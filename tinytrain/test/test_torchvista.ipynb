# %%
"""使用网页版jupyter notebook运行以下代码来显示网络结构图"""
import torch
from tinytrain import YOLOCore
from torchvista import trace_model

yolo = YOLOCore(link_file=r"example_projects\cls\link.toml")
model = yolo.get_model()

model.eval()  # 设置为评估模式

# 准备一个示例输入，用于模型转换和推理
dummy_input = torch.randn(1, 3, 28, 28)  # 形状为 [batch_size, channels, height, width]

trace_model(model, dummy_input)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 from tinytrain import YOLOCore
#       4 from torchvista import trace_model
# ----> 6 yolo = YOLOCore(link_file=r"D:\project\python_code\TinyTrain-main\example_projects\cls\link.toml")
#       7 model = yolo.get_model()
#       9 model.eval()  # 设置为评估模式
#
# File D:\project\python_code\TinyTrain-main\tinytrain\engine\core.py:49, in Core.__init__(self, link_file, callback, *args, **kwargs)
#      42 """
#      43 初始化 Core，加载 link 配置并注册各 engine 的占位符。
#      44
#      45 Args:
#      46     link_file (str | Path, optional): link 配置文件路径（yaml / toml）。
#      47 """
#      48 # register manager
# ---> 49 self.config_manager = TTConfigManager(link_file=link_file)
#      50 self.task: str = self.config_manager.core["task"]
#      52 # register components
#
# ...
