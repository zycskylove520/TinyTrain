# %%
"""使用网页版jupyter notebook运行以下代码来显示网络结构图"""
import torch
from TinyTrain import YOLOCore
from torchvista import trace_model

yolo = YOLOCore(link_file=r"D:\project\python_code\TinyTrain-main\projects\cls\link.toml")
yolo._bind_model()

model = yolo.model
model.eval()  # 设置为评估模式

# 准备一个示例输入，用于模型转换和推理
dummy_input = torch.randn(1, 3, 28, 28)  # 形状为 [batch_size, channels, height, width]

trace_model(model, dummy_input)
# Out:
# D:\SoftWare\Python312\Lib\site-packages\torchvision\transforms\_functional_video.py:6: UserWarning: The 'torchvision.transforms._functional_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms.functional' module instead.
#   warnings.warn(
# D:\SoftWare\Python312\Lib\site-packages\torchvision\transforms\_transforms_video.py:22: UserWarning: The 'torchvision.transforms._transforms_video' module is deprecated since 0.12 and will be removed in the future. Please use the 'torchvision.transforms' module instead.
#   warnings.warn(
# D:\SoftWare\Python312\Lib\site-packages\torchvista\tracer.py:67: UserWarning: Torchaudio's I/O functions now support par-call bakcend dispatch. Importing backend implementation directly is no longer guaranteed to work. Please use `backend` keyword with load/save/info function, instead of calling the udnerlying implementation directly.
#   if hasattr(mod, '__path__'):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 from TinyTrain import YOLOCore
#       4 from torchvista import trace_model
# ----> 6 yolo = YOLOCore(link_file=r"../models/yolo/task/detect/cfg/link.toml")
#       7 yolo._bind_model()
#       9 model = yolo.model
#
# File D:\project\python_code\TinyTrain-main\TinyTrain\engine\core.py:43, in Core.__init__(self, link_file)
#      40 self.tuner = None
#      42 # register manager
# ---> 43 self.config_manager = ConfigManager(link_file=link_file)
#      45 # 保存当前主脚本路径（用于 DDP 启动）
#      46 frame = inspect.stack()[-1]
#
# File D:\project\python_code\TinyTrain-main\TinyTrain\cfg\config_manager.py:13, in ConfigManager.__init__(self, link_file, **kwargs)
#      11 super().__init__(link_file=link_file, **kwargs)
#      12 self.link = None
# ---> 13 self.parse_link_file(link_file)
#
# File D:\project\python_code\TinyTrain-main\TinyTrain\cfg\config_manager.py:24, in ConfigManager.parse_link_file(self, link_file)
#      22 if not isinstance(value, str):
#      23     raise ValueError(f"{key} must be a valid file")
# ---> 24 value = check_file(value)
#      25 if value.suffix != ".toml":
#      26     raise ValueError(f"{key} must be '.toml' file")
#
# File D:\project\python_code\TinyTrain-main\TinyTrain\utils\checks.py:80, in check_file(file)
#      78 # 检查搜索结果
#      79 if not found_files:
# ---> 80     raise FileNotFoundError(f"'{file}' does not exist")
#      81 elif len(found_files) > 1:
#      82     raise FileNotFoundError(f"Multiple files match '{file}'. Specify exact path: {found_files}")
#
# FileNotFoundError: 'cfg\core\core.toml' does not exist
